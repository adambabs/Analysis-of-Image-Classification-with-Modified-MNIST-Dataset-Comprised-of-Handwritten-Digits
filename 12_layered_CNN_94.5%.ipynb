# %% [markdown]
# <a href="https://colab.research.google.com/github/sbakhit/Modified-MNIST/blob/master/Final_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import torch.nn as nn


class Net(nn.Module):
    def __init__(self, num_classes=10):
        super(Net, self).__init__()
        # Defining a 2D convolution layer
        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, stride=1),
            nn.BatchNorm2d(32),
            nn.ReLU())
        self.layer2 = nn.Sequential(
            nn.Conv2d(32, 32, kernel_size=3, stride=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.layer3 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, stride=1),
            nn.BatchNorm2d(64),
            nn.ReLU())
        self.layer4 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.layer5 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, stride=1),
            nn.BatchNorm2d(128),
            nn.ReLU())
        self.layer6 = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=3, stride=1),
            nn.BatchNorm2d(128),
            nn.ReLU())
        self.layer7 = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=3, stride=1),
            nn.BatchNorm2d(128),
            nn.ReLU())
        self.layer8 = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=3, stride=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.layer9 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, stride=1),
            nn.BatchNorm2d(256),
            nn.ReLU())
        self.layer10 = nn.Sequential(
            nn.Conv2d(256, 256, kernel_size=3, stride=1),
            nn.BatchNorm2d(256),
            nn.ReLU())
        self.layer11 = nn.Sequential(
            nn.Conv2d(256, 256, kernel_size=3, stride=1),
            nn.BatchNorm2d(256),
            nn.ReLU())
        self.layer12 = nn.Sequential(
            nn.Conv2d(256, 256, kernel_size=3, stride=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        
        self.drop_out = nn.Dropout()

        # Defining another 2D convolution layer
        self.fc1 = nn.Sequential(
            nn.Linear(1*1*256, 4096)
        )
        self.fc2 = nn.Sequential(
            nn.Linear(4096, 256)
        )
        self.fc3 = nn.Sequential(
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = self.layer6(out)
        out = self.layer7(out)
        out = self.layer8(out)
        out = self.layer9(out)
        out = self.layer10(out)
        out = self.layer11(out)
        out = self.layer12(out)
        out = out.reshape(out.size(0), -1)
        out = self.drop_out(out)
        out = self.fc1(out)
        out = self.fc2(out)
        out = self.fc3(out)
        return out

# %%
#!/usr/bin/env python3

# FOR TESTING ON VALIDATION DATASET

import numpy as np
import torch
import pandas as pd
import cv2
import inspect
import matplotlib.pyplot as plt
from torch import nn, optim
from time import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score, accuracy_score
from torch.autograd import Variable
from matplotlib import pyplot as plt

# number of times we iterate over the training set
EPOCHS = 40
LEARNING_RATE = 0.001
BATCH_SIZE = 256
TRAIN_PATH = '/content/drive/My Drive/McGill/comp551/data/train_max_x'
TEST_PATH = '/content/drive/My Drive/McGill/comp551/data/test_max_x'
TARGETS_PATH = '/content/drive/My Drive/McGill/comp551/data/train_max_y.csv'
THRESH = 240

# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

def calculate_metric(metric_fn, true_y, pred_y):
    # multi class problems need to have averaging method
    if "average" in inspect.getfullargspec(metric_fn).args:
        return metric_fn(true_y, pred_y, average="macro")
    else:
        return metric_fn(true_y, pred_y)
    
def print_scores(r, a, batch_size):
    # just an utility printing function
    for name, scores in zip(("recall", "accuracy"), (r, a)):
        print(f"\t{name.rjust(14, ' ')}: {sum(scores)/batch_size:.4f}")


print('torch.cuda.device_count(): {0}'.format(torch.cuda.device_count()))
print('torch.cuda.get_device_name: {0}'.format(torch.cuda.get_device_name(0)))
# load images as a numpy array
train_dataset = np.array(np.load(TRAIN_PATH, allow_pickle=True))
train_dataset = np.array([cv2.threshold(i, THRESH, 255, cv2.THRESH_BINARY)[1] for i in train_dataset])
train_dataset = train_dataset / 255.0

targets = pd.read_csv(TARGETS_PATH, delimiter=',', skipinitialspace=True)
targets = targets.to_numpy()
# remove id column
targets = targets[:, 1]
targets = targets.astype(int)

X_train, X_test, y_train, y_test = train_test_split(train_dataset, targets, test_size=0.2, random_state=42)
# Clean memory
len_train_dataset = len(X_train)
train_dataset = None
targets = None

X_train = torch.from_numpy(X_train)
y_train = torch.from_numpy(y_train)
X_test = torch.from_numpy(X_test)
y_test = torch.from_numpy(y_test)
y_train = y_train.long()
y_test = y_test.long()

X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1], X_train.shape[2])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1], X_test.shape[2])

train_dataset = torch.utils.data.TensorDataset(X_train,y_train)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, num_workers=8)
test_dataset = torch.utils.data.TensorDataset(X_test,y_test)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, num_workers=8)

# defining the model
model = Net().to(device)

criterion = nn.CrossEntropyLoss()
# optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

time0 = time()
batches = len(train_loader)
val_batches = len(test_loader)
train_losses_arr = []
val_losses_arr = []
train_acc_arr = []
val_acc_arr = []

for e in range(EPOCHS):
  running_loss = 0.0

  # set model to training
  model.train()
  correct = 0
  total = 0
  for i, data in enumerate(train_loader, 0):
    inputs, labels = data
    inputs, labels = inputs.to(device), labels.to(device)

    # clearing the Gradients of the model parameters
    optimizer.zero_grad()

    # prediction for training
    output_train = model(inputs)
    
    # computing the training loss
    loss_train = criterion(output_train, labels)

    # computing the updated weights of all the model parameters
    loss_train.backward()

    # And optimizes its weights here
    optimizer.step()

    running_loss += loss_train.item()

    _, predicted = torch.max(output_train.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum().item()

  # releasing unnecessary memory in GPU
  if torch.cuda.is_available():
      torch.cuda.empty_cache()

  # ----------------- VALIDATION  ----------------- 
  val_loss = 0
  recall, accuracy = [], []
  
  # set model to evaluating (testing)
  model.eval()

  # prediction for validation set
  # correct = 0
  # total = 0
  with torch.no_grad():
    for data in test_loader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        output = model(images)
        val_loss += criterion(output, labels)
        _, predicted = torch.max(output.data, 1)
        # total += labels.size(0)
        # correct += (predicted == labels).sum().item()
        
        for acc, metric in zip((recall, accuracy), 
                                (recall_score, accuracy_score)):
            acc.append(
                calculate_metric(metric, labels.cpu(), predicted.cpu())
            )
  # print("Epoch {} - Training loss: {} - Validation accuracy: {}".format(e, running_loss / len_train_dataset, 100 * correct / total))
  train_acc = correct/total
  val_acc = sum(accuracy)/len(accuracy)
  print(f"Epoch {e+1}/{EPOCHS}, training accuarcy: {train_acc}, validation accuarcy: {val_acc}")
  print(f"Epoch {e+1}/{EPOCHS}, training loss: {running_loss/batches}, validation loss: {val_loss/val_batches}")
  print_scores(recall, accuracy, val_batches)
  train_losses_arr.append(running_loss/batches) # for plotting learning curve
  val_losses_arr.append(val_loss/val_batches)
  train_acc_arr.append(train_acc)
  val_acc_arr.append(val_acc)

print("\nTraining Time (in minutes) =", (time() - time0) / 60)

plt.subplot(1, 2, 1)
plt.plot(train_acc_arr)
plt.plot(val_acc_arr)
plt.title('Model accuracy')
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy [%]')
# x=range(0, EPOCHS+1, 5)
y=np.arange(0, 1.001, 0.05)
plt.yticks(y)
# plt.xticks(x)
plt.legend(['training set', 'validation set'], loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(train_losses_arr)
plt.plot(val_losses_arr)
plt.title('Cross-Entropy Loss')
plt.xlabel('Epoch Number')

# x=range(0, EPOCHS+1, 5)
# plt.xticks(x)
plt.legend(['training set', 'validation set'], loc='upper right')

plt.show()
# # accuracy on validation set
# print("\nModel Accuracy =", (100 * correct / total))
# Out:
# torch.cuda.device_count(): 1
# torch.cuda.get_device_name: Tesla P100-PCIE-16GB
# Epoch 1/40, training accuarcy: 0.264725, validation accuarcy: 0.31201171875
# Epoch 1/40, training loss: 2.073434226072518, validation loss: 1.8553516864776611
# 	        recall: 0.1488
# 	      accuracy: 0.3120
# Epoch 2/40, training accuarcy: 0.40475, validation accuarcy: 0.41943359375
# Epoch 2/40, training loss: 1.6006185135264306, validation loss: 1.5592050552368164
# 	        recall: 0.2368
# 	      accuracy: 0.4194
# Epoch 3/40, training accuarcy: 0.499475, validation accuarcy: 0.4904296875
# Epoch 3/40, training loss: 1.3839332100692068, validation loss: 1.421137809753418
# 	        recall: 0.2922
# 	      accuracy: 0.4904
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# Epoch 4/40, training accuarcy: 0.615925, validation accuarcy: 0.65068359375
# Epoch 4/40, training loss: 1.091308425186546, validation loss: 1.0988694429397583
# 	        recall: 0.4446
# 	      accuracy: 0.6507
# Epoch 5/40, training accuarcy: 0.725475, validation accuarcy: 0.651171875
# Epoch 5/40, training loss: 0.802763033065067, validation loss: 0.997492253780365
# 	        recall: 0.4684
# 	      accuracy: 0.6512
# Epoch 6/40, training accuarcy: 0.779025, validation accuarcy: 0.66728515625
# Epoch 6/40, training loss: 0.655155284199745, validation loss: 0.9629560708999634
# 	        recall: 0.5053
# 	      accuracy: 0.6673
# Epoch 7/40, training accuarcy: 0.8315, validation accuarcy: 0.74765625
# Epoch 7/40, training loss: 0.5303904626779495, validation loss: 0.8141323328018188
# 	        recall: 0.5525
# 	      accuracy: 0.7477
# Epoch 8/40, training accuarcy: 0.862525, validation accuarcy: 0.84912109375
# Epoch 8/40, training loss: 0.45069157223033296, validation loss: 0.48708149790763855
# 	        recall: 0.6768
# 	      accuracy: 0.8491
# Epoch 9/40, training accuarcy: 0.880825, validation accuarcy: 0.88154296875
# Epoch 9/40, training loss: 0.3908060723619097, validation loss: 0.4320559501647949
# 	        recall: 0.6944
# 	      accuracy: 0.8815
# Epoch 10/40, training accuarcy: 0.8963, validation accuarcy: 0.88759765625
# Epoch 10/40, training loss: 0.34517883143986866, validation loss: 0.43502673506736755
# 	        recall: 0.6979
# 	      accuracy: 0.8876
# Epoch 11/40, training accuarcy: 0.906875, validation accuarcy: 0.8814453125
# Epoch 11/40, training loss: 0.30804523009403495, validation loss: 0.47273096442222595
# 	        recall: 0.6983
# 	      accuracy: 0.8814
# Epoch 12/40, training accuarcy: 0.915575, validation accuarcy: 0.88046875
# Epoch 12/40, training loss: 0.280674224826181, validation loss: 0.5262853503227234
# 	        recall: 0.7213
# 	      accuracy: 0.8805
# Epoch 13/40, training accuarcy: 0.92245, validation accuarcy: 0.89697265625
# Epoch 13/40, training loss: 0.2578513298634511, validation loss: 0.44209185242652893
# 	        recall: 0.7346
# 	      accuracy: 0.8970
# Epoch 14/40, training accuarcy: 0.9266, validation accuarcy: 0.90078125
# Epoch 14/40, training loss: 0.24359492701330002, validation loss: 0.3994121253490448
# 	        recall: 0.7407
# 	      accuracy: 0.9008
# Epoch 15/40, training accuarcy: 0.93395, validation accuarcy: 0.82509765625
# Epoch 15/40, training loss: 0.21717138635884425, validation loss: 0.737862765789032
# 	        recall: 0.6992
# 	      accuracy: 0.8251
# Epoch 16/40, training accuarcy: 0.938475, validation accuarcy: 0.89228515625
# Epoch 16/40, training loss: 0.20553115636679778, validation loss: 0.48417529463768005
# 	        recall: 0.7482
# 	      accuracy: 0.8923
# Epoch 17/40, training accuarcy: 0.946525, validation accuarcy: 0.909765625
# Epoch 17/40, training loss: 0.18135389139887634, validation loss: 0.38251981139183044
# 	        recall: 0.7902
# 	      accuracy: 0.9098
# Epoch 18/40, training accuarcy: 0.94835, validation accuarcy: 0.914453125
# Epoch 18/40, training loss: 0.17206231186724014, validation loss: 0.3776607811450958
# 	        recall: 0.7887
# 	      accuracy: 0.9145
# Epoch 19/40, training accuarcy: 0.951275, validation accuarcy: 0.9205078125
# Epoch 19/40, training loss: 0.16856838558699674, validation loss: 0.3101672828197479
# 	        recall: 0.7942
# 	      accuracy: 0.9205
# Epoch 20/40, training accuarcy: 0.9541, validation accuarcy: 0.9236328125
# Epoch 20/40, training loss: 0.15852166242470409, validation loss: 0.34801924228668213
# 	        recall: 0.8223
# 	      accuracy: 0.9236
# Epoch 21/40, training accuarcy: 0.95925, validation accuarcy: 0.9048828125
# Epoch 21/40, training loss: 0.1397515563116332, validation loss: 0.3987457752227783
# 	        recall: 0.7784
# 	      accuracy: 0.9049
# Epoch 22/40, training accuarcy: 0.961125, validation accuarcy: 0.90390625
# Epoch 22/40, training loss: 0.1324692988044517, validation loss: 0.40852051973342896
# 	        recall: 0.7926
# 	      accuracy: 0.9039
# Epoch 23/40, training accuarcy: 0.96365, validation accuarcy: 0.90107421875
# Epoch 23/40, training loss: 0.12633902152442628, validation loss: 0.4698795974254608
# 	        recall: 0.8089
# 	      accuracy: 0.9011
# Epoch 24/40, training accuarcy: 0.9658, validation accuarcy: 0.866015625
# Epoch 24/40, training loss: 0.11964408846892369, validation loss: 0.6714342832565308
# 	        recall: 0.7690
# 	      accuracy: 0.8660
# Epoch 25/40, training accuarcy: 0.9662, validation accuarcy: 0.90869140625
# Epoch 25/40, training loss: 0.12097131717167083, validation loss: 0.4566987454891205
# 	        recall: 0.8353
# 	      accuracy: 0.9087
# Epoch 26/40, training accuarcy: 0.969275, validation accuarcy: 0.926953125
# Epoch 26/40, training loss: 0.11087356605062819, validation loss: 0.372183620929718
# 	        recall: 0.8310
# 	      accuracy: 0.9270
# Epoch 27/40, training accuarcy: 0.969975, validation accuarcy: 0.91083984375
# Epoch 27/40, training loss: 0.10792686385666109, validation loss: 0.43991899490356445
# 	        recall: 0.8233
# 	      accuracy: 0.9108
# Epoch 28/40, training accuarcy: 0.97035, validation accuarcy: 0.91826171875
# Epoch 28/40, training loss: 0.10266763295764757, validation loss: 0.45246514678001404
# 	        recall: 0.8466
# 	      accuracy: 0.9183
# Epoch 29/40, training accuarcy: 0.974025, validation accuarcy: 0.92646484375
# Epoch 29/40, training loss: 0.09440280676220253, validation loss: 0.4082094728946686
# 	        recall: 0.8386
# 	      accuracy: 0.9265
# Epoch 30/40, training accuarcy: 0.974725, validation accuarcy: 0.92421875
# Epoch 30/40, training loss: 0.09190669480212935, validation loss: 0.4241511821746826
# 	        recall: 0.8248
# 	      accuracy: 0.9242
# Epoch 31/40, training accuarcy: 0.975875, validation accuarcy: 0.9376953125
# Epoch 31/40, training loss: 0.08991648569987838, validation loss: 0.3426799178123474
# 	        recall: 0.8529
# 	      accuracy: 0.9377
# Epoch 32/40, training accuarcy: 0.9769, validation accuarcy: 0.90869140625
# Epoch 32/40, training loss: 0.08303448107022389, validation loss: 0.5393375754356384
# 	        recall: 0.8312
# 	      accuracy: 0.9087
# Epoch 33/40, training accuarcy: 0.97855, validation accuarcy: 0.9228515625
# Epoch 33/40, training loss: 0.07504113811026712, validation loss: 0.5327996015548706
# 	        recall: 0.8180
# 	      accuracy: 0.9229
# Epoch 34/40, training accuarcy: 0.98035, validation accuarcy: 0.9345703125
# Epoch 34/40, training loss: 0.07159918474306347, validation loss: 0.37331992387771606
# 	        recall: 0.8638
# 	      accuracy: 0.9346
# Epoch 35/40, training accuarcy: 0.97735, validation accuarcy: 0.932421875
# Epoch 35/40, training loss: 0.08254525152029125, validation loss: 0.4357980191707611
# 	        recall: 0.8540
# 	      accuracy: 0.9324
# Epoch 36/40, training accuarcy: 0.980925, validation accuarcy: 0.92138671875
# Epoch 36/40, training loss: 0.0747971684927014, validation loss: 0.4481426179409027
# 	        recall: 0.8360
# 	      accuracy: 0.9214
# Epoch 37/40, training accuarcy: 0.983225, validation accuarcy: 0.93486328125
# Epoch 37/40, training loss: 0.06253503445108795, validation loss: 0.40523257851600647
# 	        recall: 0.8550
# 	      accuracy: 0.9349
# Epoch 38/40, training accuarcy: 0.98495, validation accuarcy: 0.93994140625
# Epoch 38/40, training loss: 0.05582616334057348, validation loss: 0.3869314193725586
# 	        recall: 0.8640
# 	      accuracy: 0.9399
# Epoch 39/40, training accuarcy: 0.983875, validation accuarcy: 0.934765625
# Epoch 39/40, training loss: 0.06262009507816309, validation loss: 0.44685253500938416
# 	        recall: 0.8365
# 	      accuracy: 0.9348
# Epoch 40/40, training accuarcy: 0.983225, validation accuarcy: 0.91689453125
# Epoch 40/40, training loss: 0.06341772530061804, validation loss: 0.5338342785835266
# 	        recall: 0.7891
# 	      accuracy: 0.9169
#
# Training Time (in minutes) = 32.149011647701265

# %%
plt.subplot(1, 2, 1)
plt.plot(train_acc_arr)
plt.plot(val_acc_arr)
plt.title('Model accuracy')
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy [%]')
x=range(0, EPOCHS+1, 5)
y=np.arange(0, 1.001, 0.05)
plt.yticks(y)
plt.xticks(x)
plt.legend(['training set', 'validation set'], loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(train_losses_arr)
plt.plot(val_losses_arr)
plt.title('Cross-Entropy Loss')
plt.xlabel('Epoch Number')

x=range(0, EPOCHS+1, 5)
plt.xticks(x)
plt.legend(['training set', 'validation set'], loc='upper right')

plt.show()

# %%
#!/usr/bin/env python3

# FOR MAKING PREDICTIONS ON TEST SET AND SAVING TO CSV

import numpy as np
import torch
import pandas as pd
import cv2
import shutil
from torch import nn, optim
from time import time
from sklearn.model_selection import train_test_split
from torch.autograd import Variable
from matplotlib import pyplot as plt

# number of times we iterate over the training set
EPOCHS = 100
LEARNING_RATE = 0.001
BATCH_SIZE = 672
TRAIN_PATH = '/content/drive/My Drive/McGill/comp551/data/train_max_x'
TEST_PATH = '/content/drive/My Drive/McGill/comp551/data/test_max_x'
TARGETS_PATH = '/content/drive/My Drive/McGill/comp551/data/train_max_y.csv'
THRESH = 240

# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')


def main():
    print('torch.cuda.device_count(): {0}'.format(torch.cuda.device_count()))
    print('torch.cuda.get_device_name: {0}'.format(torch.cuda.get_device_name(0)))
    # load images as a numpy array
    X_train = np.array(np.load(TRAIN_PATH, allow_pickle=True))
    X_train = np.array([cv2.threshold(i, THRESH, 255, cv2.THRESH_BINARY)[1] for i in X_train])
    X_train = X_train / 255.0

    X_test = np.array(np.load(TEST_PATH, allow_pickle=True))
    X_test = np.array([cv2.threshold(i, THRESH, 255, cv2.THRESH_BINARY)[1] for i in X_test])
    X_test = X_test / 255.0

    y_train = pd.read_csv(TARGETS_PATH, delimiter=',', skipinitialspace=True)
    y_train = y_train.to_numpy()
    # remove id column
    y_train = y_train[:, 1]
    y_train = y_train.astype(int)

    # Clean memory
    len_train_dataset = len(X_train)

    X_train = torch.from_numpy(X_train)
    y_train = torch.from_numpy(y_train)
    X_test = torch.from_numpy(X_test)
    y_train = y_train.long()

    X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1], X_train.shape[2])
    X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1], X_test.shape[2])

    train_dataset = torch.utils.data.TensorDataset(X_train,y_train)
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, num_workers=8)
    test_loader = torch.utils.data.DataLoader(X_test, batch_size=BATCH_SIZE, num_workers=8)

    # defining the model
    model = Net().to(device)

    criterion = nn.CrossEntropyLoss()
    # optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

    time0 = time()

    for e in range(EPOCHS):
      running_loss = 0.0
      for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        # clearing the Gradients of the model parameters
        optimizer.zero_grad()

        # prediction for training
        output_train = model(inputs)
        
        # computing the training loss
        loss_train = criterion(output_train, labels)

        # computing the updated weights of all the model parameters
        loss_train.backward()

        # And optimizes its weights here
        optimizer.step()

        running_loss += loss_train.item()
      else:
            print("Epoch {} - Training loss: {}".format(e, running_loss / len_train_dataset))

    print("\nTraining Time (in minutes) =", (time() - time0) / 60)

    # prediction for test set
    predictions = np.array([])
    with torch.no_grad():
      for images in test_loader:
        images = images.to(device)
        output = model(images)
        _, predicted = torch.max(output.data, 1)
        predictions = np.append(predictions, predicted.cpu().numpy())

    predictions = predictions.astype(int)
    Id = list(range(0, 10000))
    Id = np.asarray(Id)
    results = pd.DataFrame({'Id': Id, 'Label': predictions}, columns=['Id', 'Label'])
    from google.colab import files
    results.to_csv('predictions.csv', index=False)
    shutil.move("/content/predictions.csv", "/content/drive/My Drive/McGill/comp551/predictions.csv")
    print('Results have been saved to predictions.csv')

if __name__ == '__main__':
    main()
# Out:
# torch.cuda.device_count(): 1
# torch.cuda.get_device_name: Tesla P100-PCIE-16GB
# Epoch 0 - Training loss: 0.0032704003858566285
# Epoch 1 - Training loss: 0.0029089065623283386
# Epoch 2 - Training loss: 0.002827518105506897
# Epoch 3 - Training loss: 0.0024329508543014526
# Epoch 4 - Training loss: 0.002178996772766113
# Epoch 5 - Training loss: 0.0019570931363105774
# Epoch 6 - Training loss: 0.0015498412847518921
# Epoch 7 - Training loss: 0.0011921281003952025
# Epoch 8 - Training loss: 0.0009742726159095764
# Epoch 9 - Training loss: 0.000797192497253418
